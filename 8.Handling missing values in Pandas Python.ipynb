# %% [markdown]
# dropna And fillna

# %%
import pandas as pd

# %%
var=pd.read_csv("C:\\Users\\PMYLS\\8.sample_data_40_entries.csv")

# %%
var
# Out:
#          Name   Age Occupation    Salary
# 0    Person_1  43.0     Doctor   92982.0
# 1    Person_2  35.0     Doctor   81507.0
# 2    Person_3  38.0    Teacher  110001.0
# 3    Person_4  26.0    Teacher   93905.0
# 4    Person_5  53.0   Engineer   46465.0
# 5    Person_6  29.0     Lawyer  115566.0
# 6    Person_7  24.0    Teacher  114847.0
# 7    Person_8  25.0    Teacher   49302.0
# 8    Person_9  25.0     Lawyer   94557.0
# 9   Person_10  26.0     Doctor   63873.0
# 10  Person_11  30.0     Artist   83137.0
# 11  Person_12  32.0    Teacher   73869.0
# 12  Person_13   NaN    Teacher   60652.0
# 13  Person_14  48.0     Artist   89730.0
# 14  Person_15  59.0    Teacher   60026.0
# 15  Person_16  56.0   Engineer  109396.0
# 16  Person_17  59.0     Artist   31362.0
# 17  Person_18  52.0     Lawyer   99236.0
# 18  Person_19  36.0     Lawyer  105336.0
# 19  Person_20  48.0     Doctor   83312.0
# 20  Person_21  49.0     Artist   95363.0
# 21        NaN   NaN        NaN       NaN
# ...

# %%
#using dropna function function we remove all NONE values/missing values
#var.dropna()

# %%
#using dropna function function and giving it axis value(0=row,1=col) we remove all NONE values/missing values
#var.dropna(axis=0)

# %%
#var.dropna(axis=1)

# %%
#how=any,how=all
#var.dropna(how="all")

# %%
#remove null value across any column
#var.dropna(subset=["Salary"])

# %%
#remove all none values and replace in new daataset
#var.dropna(inplace=True)
#var

# %%
#to remove single null value
#var.dropna(thresh=1)
#to remove  multiple null values
#var.dropna(thresh=2)

# %%
#fillna to fill any none value
#var.fillna("PYTON")

# %%
#to  fill any particular data in any particular column
#var.fillna({"Age":"CHILD","Name":"Noname","Occupation":"BYROZGAR","Salary":"No salary"})

# %%
#to filll nonoe value with its previous data or value 
#see changre in line 37-38
#var.fillna(method="ffill")
#see changre in line 38-39
#var.fillna(method="bfill")

# %%
#inplace:to fill all none values with 12
#var.fillna(12,inplace=True)

# %%
#var

# %%
#rows having  only 1 none can be now replaced with python
#var.fillna("python",limit=1)

# %% [markdown]
# replace and interpolate :

# %%
#var.replace(to_replace=25,value=1)

# %%
#another method for replacement is regex
#also replace data using method
#var.replace("Artist",method="ffill")

# %%
#var.replace(39,method="ffill",limit=1)

# %% [markdown]
# interpolate: to fill any missing data autoamatically from abserving previous data and it  handles numbr data  linearly.there are methods to handle data

# %%
#var.interpolate()
#var.interpolate(method="linear")

# %%
#also limt and its direction is used
#var.interpolate(limit_direction="forward",limit=1)

# %%
#to decide either we want to applly interpolate on none data or not
#var.interpolate(area="inside")
var.interpolate(limit_area="outside")
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_10188\3787971977.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(limit_area="outside")
#          Name   Age Occupation    Salary
# 0    Person_1  43.0     Doctor   92982.0
# 1    Person_2  35.0     Doctor   81507.0
# 2    Person_3  38.0    Teacher  110001.0
# 3    Person_4  26.0    Teacher   93905.0
# 4    Person_5  53.0   Engineer   46465.0
# 5    Person_6  29.0     Lawyer  115566.0
# 6    Person_7  24.0    Teacher  114847.0
# 7    Person_8  25.0    Teacher   49302.0
# 8    Person_9  25.0     Lawyer   94557.0
# 9   Person_10  26.0     Doctor   63873.0
# 10  Person_11  30.0     Artist   83137.0
# 11  Person_12  32.0    Teacher   73869.0
# 12  Person_13   NaN    Teacher   60652.0
# 13  Person_14  48.0     Artist   89730.0
# 14  Person_15  59.0    Teacher   60026.0
# ...
